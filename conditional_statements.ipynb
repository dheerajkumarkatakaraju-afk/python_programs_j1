# %% [markdown]
# # conditional statements in python
# 1. Python have 4 types of conditional statements
# 2. `if` statement
# 3. `elif` statement
# 4. `else` statement
# 5. `nested` statements
#
# ```python
# if (condition):
#     statement
#     statement..
#  ```
#
#  ```python if,else
#  if(condition):
#      statements
#      statements...
#  else:
#      statements
#      statements...
# ```
#
# ```python if,elif,else
# if(condition):
#     statement
# elif(condition):
#     statements
# elif(condition):
#     statement
# else:
#     statements..
# ```

# %%
#write a pogram to find the given number is even number
num=int(input("please enter number here:"))
if(num%2 == 0):
    print(num,"is even number")
# Out:
# please enter number here: 123

# %%
#write a program to find the given number is even number or odd number
number = int(input("please enter number here:"))
if(number%2 == 0):
   print(number,"is even number")
else:
    print(number,"is odd number")
# Out:
# please enter number here: 354646
# 354646 is even number

# %%
#write a pogram to find the given number is positive or negitive or zero?
n=int(input("enter number here:"))
if (n>0):
    print(n,"is positive")
elif (n>0):
    print(n,"is negative")
else:
    print(n,"is zero")
# Out:
# enter number here: 0
# 0 is zero

# %%
"""
write a pogram to find the student grades based on marks
1.if student  marks in between 100 to 80 then grade is A
2.if student  marks in between 100 to 80 then grade is B
3.if student  marks in between 100 to 80 then grade is C
4.if student  marks in between 100 to 80 then grade is D
5.if student  marks in between 100 to 80 then grade is Fail
6.if other than above mark expected output should be please enter correct marks!
"""
marks=int(input("enter student marks here:"))
if (marks>=80 and marks<=100):
     print(marks,"is A grade")
elif (marks>=60 and marks<=79):
     print(marks,"is B grade")
elif (marks>=40 and marks<=59):
     print(marks,"is C grade")
elif (marks>=25 and marks<=39):
     print(marks,"is D grade")
elif (marks>=0 and marks<=24):
     print(marks,"is Fail")
else:
     print(marks,"is not correct marks, please enter correct marks")
# Out:
# enter student marks here: 85
# 85 is A grade

# %%
# write a program to find the largest number from three numbers
# write a program to find the largest year or non leap year
# write a program to check login credentials using conditional statements

number1 = input("Enter the first number: ")
number2 = input("Enter the second number: ")
number3 = input("Enter the third number: ")

if number1 > number2:
    if number1 > number3:
        largest = number1
    else:
        largest = number3
else:
    if number2 > number3:
        largest = number2
    else:
        largest = number3

print("The largest number is:", largest)

year = input("Enter a year: ")

if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print(year, "is a leap year")
        else:
            print(year, "is not a leap year")
    else:
        print(year, "is a leap year")
else:
    print(year, "is not a leap year")
3. Login Credentials

stored_username = "user123"
stored_password = "password123"

entered_username = input("Enter username: ")
entered_password = input("Enter password: ")

if entered_username == stored_username:
    if entered_password == stored_password:
        print("Login successful!")
    else:
        print("Invalid password")
else:
    print("Invalid username")
# Out:
#   Cell In[29], line 34
#     3. Login Credentials
#        ^
# SyntaxError: invalid syntax
