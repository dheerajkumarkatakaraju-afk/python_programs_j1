# %%
# data types in python
1.python have 3 data types
2.int(integer)
2.str(string)
3.float(decimals)

# %%
name="dheeraj123"
age=26
salary=40000000000
print(name)
print(age)
print(salary)
# Out:
# dheeraj123
# 26
# 40000000000

# %%
data="120"
print(data)
print(type(data))
# Out:
# 120
# <class 'str'>

# %%
a=100
b=200
print(a+b)
# Out:
# 300

# %%
v1=100
v2=100.25
print(v1+v2)
# Out:
# 200.25
